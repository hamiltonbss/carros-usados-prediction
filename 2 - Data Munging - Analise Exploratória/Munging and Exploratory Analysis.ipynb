# %%
import pandas as pd

# %%
DadosBrutos = pd.read_csv('DadosBrutos.csv')

# %%
DadosBrutos
# Out:
#                                     modelo combustivel       cor   ano  \
# 0         FIAT STRADA RANCH CD 1.3 AT 2023        FLEX     PRETO  2023
# 1          FIAT STRADA VOLCANO 1.3 CD 2023        FLEX  VERMELHO  2023
# 2                  RENAULT KWID ZEN 2 2023        FLEX    BRANCO  2023
# 3     TOYOTA COROLLA XEI 2.0L FFV CVT 2023        FLEX  VERMELHO  2023
# 4        CHEVROLET ONIX PLUS 10MT LT2 2023        FLEX     PRATA  2023
# ...                                    ...         ...       ...   ...
# 4173                FORD RURAL WILLYS 1967    GASOLINA   AMARELO  1967
# 4174         VOLKSWAGEN FUSCA 1200 2P 1965    GASOLINA     VERDE  1965
# 4175            VOLKSWAGEN FUSCA 1300 1965    GASOLINA    BRANCO  1965
# 4176               WILLYS AERO WILLYS 1961    GASOLINA    BRANCO  1961
# 4177    LOTUS - NÃS COMPRAMOS SEU CARRO 0        FLEX    BRANCO     0
#
#            km         valor
# 0       0.000  R$139.800,00
# 1      18.000  R$119.800,00
# ...
